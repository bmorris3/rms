# %%
import numpy as np

planet, transit, time, offset = np.loadtxt('/Users/bmmorris/git/trappist1sc/data/ttv_agol.dat', unpack=True)
time += 2457700

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(time, offset, '.')
